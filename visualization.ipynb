# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Sales_data_zone_wise.csv",index_col='Month')#converting index as month for graph to get x axis as month

# %%
df.head()
# Out:
#            Zone - A  Zone - B  Zone - C  Zone - D
# Month
# Month - 1   1483525   1748451   1523308   2267260
# Month - 2   1238428   1707421   2212113   1994341
# Month - 3   1860771   2091194   1282374   1241600
# Month - 4   1871571   1759617   2290580   2252681
# Month - 5   1244922   1606010   1818334   1326062

# %% [markdown]
# # LINE CHART

# %%
df['Zone - A'].plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
df['Zone - A'].plot();
# using semicolon for get rid of the output as shown in output 6

# %%
df.head()
# Out:
#            Zone - A  Zone - B  Zone - C  Zone - D
# Month
# Month - 1   1483525   1748451   1523308   2267260
# Month - 2   1238428   1707421   2212113   1994341
# Month - 3   1860771   2091194   1282374   1241600
# Month - 4   1871571   1759617   2290580   2252681
# Month - 5   1244922   1606010   1818334   1326062

# %%
df.columns
# Out:
# Index(['Zone - A', 'Zone - B', 'Zone - C', 'Zone - D'], dtype='object')

# %%
df.columns
# Out:
# Index(['Zone - A', 'Zone - B', 'Zone - C', 'Zone - D'], dtype='object')

# %%
df[['Zone - A', 'Zone - B', 'Zone - C', 'Zone - D']].plot(kind='line')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
df[['Zone - A', 'Zone - B', 'Zone - C', 'Zone - D']].plot(kind='line',subplots=True,figsize=(10,10));

# %%
df[['Zone - A', 'Zone - B', 'Zone - C', 'Zone - D']].plot(kind='line',subplots=True,);

# %%
plt.style.available
#decorating graphs
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('ggplot')

# %%
df[['Zone - A', 'Zone - B', 'Zone - C', 'Zone - D']].plot(kind='line',subplots=True,figsize=(10,10));

# %% [markdown]
# # BAR GRAPH

# %%
dfs=pd.read_csv("C:\\Users\\HP\\Documents\\python casestudies\\week07 casestudy\\Sales_add.csv")

# %%
dfs
# Out:
#        Month      Region      Manager  Sales_before_digital_add(in $)  \
# 0    Month-1  Region - A  Manager - A                          132921
# 1    Month-2  Region - A  Manager - C                          149559
# 2    Month-3  Region - B  Manager - A                          146278
# 3    Month-4  Region - B  Manager - B                          152167
# 4    Month-5  Region - C  Manager - B                          159525
# 5    Month-6  Region - A  Manager - B                          137163
# 6    Month-7  Region - C  Manager - C                          130625
# 7    Month-8  Region - A  Manager - A                          131140
# 8    Month-9  Region - B  Manager - C                          171259
# 9   Month-10  Region - C  Manager - B                          141956
# 10  Month-11  Region - B  Manager - C                          159339
# 11  Month-12  Region - A  Manager - A                          178939
# ...

# %%
dfs.Region.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
dfs[["Region","Manager"]].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Region,Manager'>

# %%
dfs[["Region","Manager"]].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Region,Manager'>

# %%
sns.countplot(x='Region',hue='Manager',data=dfs)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %% [markdown]
# # PIE PLOT

# %%
dfs.columns
# Out:
# Index(['Month', 'Region', 'Manager', 'Sales_before_digital_add(in $)',
#        'Sales_After_digital_add(in $)'],
#       dtype='object')

# %%
dfs.loc[:,['Sales_before_digital_add(in $)','Sales_After_digital_add(in $)','Region']]\
.groupby('Region')\
.sum()
# Out:
#             Sales_before_digital_add(in $)  Sales_After_digital_add(in $)
# Region
# Region - A                         1482049                        2388531
# Region - B                         1053665                        1601095
# Region - C                          747565                        1095096

# %%
dfs.loc[:,['Sales_before_digital_add(in $)','Sales_After_digital_add(in $)','Region']]\
.groupby('Region')\
.sum()\
.plot(kind='pie',y='Sales_before_digital_add(in $)')
# Out:
# <AxesSubplot:ylabel='Sales_before_digital_add(in $)'>

# %%
dfs.loc[:,['Sales_before_digital_add(in $)','Sales_After_digital_add(in $)','Region']]\
.groupby('Region')\
.sum()\
.plot(kind='pie',subplots=True)
# Out:
# array([<AxesSubplot:ylabel='Sales_before_digital_add(in $)'>,
#        <AxesSubplot:ylabel='Sales_After_digital_add(in $)'>], dtype=object)

# %% [markdown]
# # HISTOGRAM

# %% [markdown]
# FREQUENCIES

# %%
df.head(2)
# Out:
#            Zone - A  Zone - B  Zone - C  Zone - D
# Month
# Month - 1   1483525   1748451   1523308   2267260
# Month - 2   1238428   1707421   2212113   1994341

# %%
plt.hist(df['Zone - A'])
# Out:
# (array([3., 4., 3., 1., 5., 4., 0., 3., 5., 1.]),
#  array([1128185. , 1215814.5, 1303444. , 1391073.5, 1478703. , 1566332.5,
#         1653962. , 1741591.5, 1829221. , 1916850.5, 2004480. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Zone - A'],bins=10)
# Out:
# (array([3., 4., 3., 1., 5., 4., 0., 3., 5., 1.]),
#  array([1128185. , 1215814.5, 1303444. , 1391073.5, 1478703. , 1566332.5,
#         1653962. , 1741591.5, 1829221. , 1916850.5, 2004480. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Zone - A'],bins=15,orientation='horizontal')
# Out:
# (array([3., 2., 2., 2., 1., 1., 4., 2., 3., 0., 1., 2., 4., 1., 1.]),
#  array([1128185.        , 1186604.66666667, 1245024.33333333,
#         1303444.        , 1361863.66666667, 1420283.33333333,
#         1478703.        , 1537122.66666667, 1595542.33333333,
#         1653962.        , 1712381.66666667, 1770801.33333333,
#         1829221.        , 1887640.66666667, 1946060.33333333,
#         2004480.        ]),
#  <BarContainer object of 15 artists>)

# %%
dfs.columns
# Out:
# Index(['Month', 'Region', 'Manager', 'Sales_before_digital_add(in $)',
#        'Sales_After_digital_add(in $)'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Zone - A', 'Zone - B', 'Zone - C', 'Zone - D'], dtype='object')

# %%
df[['Zone - A', 'Zone - B', 'Zone - C', 'Zone - D']].hist()
# Out:
# array([[<AxesSubplot:title={'center':'Zone - A'}>,
#         <AxesSubplot:title={'center':'Zone - B'}>],
#        [<AxesSubplot:title={'center':'Zone - C'}>,
#         <AxesSubplot:title={'center':'Zone - D'}>]], dtype=object)

# %%
df=pd.read_csv(r"C:\Users\HP\Documents\python casestudies\week07 casestudy\dataset w7.csv")

# %%
df.head()
# Out:
#    Gender Test preparation  Total Marks
# 0    male             none           14
# 1  female             none           28
# 2  female             none           18
# 3  female             none           48
# 4  female             none           21

# %%
plt.figure()
sns.barplot(x='Gender',y='Total Marks',data=df, hue='Test preparation')
plt.title('Graph of marks basis of gender and test preparation')
# Out:
# Text(0.5, 1.0, 'Graph of marks basis of gender and test preparation')
